# %% [markdown]
# # IBM Forecasts

# %% [markdown]
# **Primary Author:** Jeff Gawrych
# **Secondary Author:** Andrew Thut
#
# This notebook collects data from the featurizer product in IBM's weather API's to produce a geojson file that can be visualised through software like ESRI or [geojson.io](https://geojson.io/)
#
# Please direct inquiries to Andrew Thut: andrew.thut@ibm.com
#
# **Background**
#
# The Weather Company (formally WSI), an IBM Business, helps people make informed decisions and take action in the face of weather. The company offers the most personalized, and actionable weather data and insights to millions of consumers, as well as thousands of marketers and businesses via Weather’s API, its business solutions division, and its own digital products from [The Weather Channel](https://weather.com/) and [Weather Underground](https://www.wunderground.com/).
#
# According to a recent [study](https://newsroom.ibm.com/2021-07-29-IBMs-The-Weather-Company-Continues-to-Be-the-Worlds-Most-Accurate-Forecaster-Overall) by ForecastWatch, The Weather Company was determined to be the most accurate global weather forecaster. The data also revealed The gap between The Weather Company and the next best overall provider has incresed every year of the study.
#
# To read more about Weather Company solutions, please click [here](https://storymaps.arcgis.com/stories/9305a40e780d4ada802a658b7e48facb).

# %% [markdown]
# **Import necessary modules**

# %%
import requests,json,datetime
from dotenv import load_dotenv
load_dotenv() #take environment variables from .env
import os

# %% [markdown]
# **Authenticate access to API**
# To make my API key secret, the code below will retrieve an API key from a file on my local machine.
#
# If you didn't want to hide the key, the code could simply be specified as follows. This approach also would not require the dotenv and os modules.
#
# APIKEY='YourAPIkey'

# %%
APIKEY=os.getenv('APIKEY')

# %% [markdown]
# **Assign Product Name and Product Number***
#
# This information as well as additional context on how to construct an API call can be found in the documentation linked below.
#
# [Current Conditions Imagery](https://ibm.co/v2EHCg) <br>
# [Forecast Conditions Imagery](https://ibm.co/WCDEFG) <br>
# [HailVision](https://ibm.co/v2HVapi): Radar derived hax hail size during previous time period<br>
# [HailZone](https://ibm.co/v2HZapi): 1km resolution hail forecast out to 30 minutes<br>
# [IceVision](https://ibm.co/v2IVapi): Radar derived ice accumulation during previous time period<br>
# [Lightning StrikeZone](https://ibm.co/v2LSZa): 1km resolution lightning forecast out to 30 minutes<br>
# [RainVision](https://ibm.co/v2RVapi): Radar derived rain accumulation during previous time period <br>
# [ShearVision](https://ibm.co/v2ShVap): Radar derived rotational shear <br>
# [SnowVision](https://ibm.co/v2SnwVa): Radar derived rain accumulation during previous time period <br>
# [Tropical Cyclone Probability](https://ibm.co/v2TCPf): Probability of major hurricane, hurricane, tropical cyclone, tropical depression and tropical storm <br>

# %%
prod_num=str(40) 
prod_name='Windspeedgustsurface'

# %% [markdown]
# **Create function and run inventory and feature calls**
#
# In the feature call, to limit the size of this query, we will use a bounding box (bbox). For assistance in identifying a bounding box for your project, please refer to the bbox finder [website](http://bboxfinder.com/#0.000000,0.000000,0.000000,0.000000).

# %%
def APIcall(calltime):
    fc = {
        "type": "FeatureCollection",
        "features": []
    }
    
####  Now make threshold calls. The thresholds for wind gust is in m/s.

    low_limit=[0.001,4.471,6.711,8.941,11.17,13.41,15.64,17.88,20.11,22.35,24.58,26.82,29.0576,31.2928,33.528,35.7632,37.9984,40.2336,42.4688,44.704,46.9392,49.1744,51.4096,53.6448,55.88,58.1152,60.3504,62.5856,64.8208,67.056,69.2912]
    high_limit=[4.471,6.711,8.941,11.17,13.41,15.64,17.88,20.11,22.35,24.58,26.82,29.0576,31.2928,33.528,35.7632,37.9984,40.2336,42.4688,44.704,46.9392,49.1744,51.4096,53.6448,55.88,58.1152,60.3504,62.5856,64.8208,67.056,69.2912,71.52]
    num_layers = len(low_limit)

########################PRODUCT INVENTORY CALL################################
    
    INVbase1 = 'https://api.weather.com/v2/tiler/info?products='+prod_num+':'+prod_name
    INVbase2 = '&apiKey='+APIKEY
    INVurl = INVbase1 + INVbase2
    print (INVurl)
    INVAPIcall = requests.get(INVurl) #Our API Call    
    INVdata = INVAPIcall.json()
    for x in range(0,1):
        t = INVdata["layers"][prod_num][prod_name]["dimensions"][x]["t"][0]
#convert unix time to real time
        timestamp=int(t)/1000
        now= datetime.datetime.utcfromtimestamp(timestamp)
        year=str(now.year)
        month=str('{:02d}'.format(now.month))
        day=str('{:02d}'.format(now.day))
        hour=str('{:02d}'.format(now.hour))
        min=str('{:02d}'.format(now.minute))
        ts=year+"-"+month+"-"+day+","+hour+min
        
########################PRODUCT FEATURE CALL################################
        base1 = 'https://api.weather.com/v2/featurizer/isoband?product='
        base2 = prod_num+':'+prod_name+'&t=' + t+'&bbox=-140.0,25.0,-50.0,50.0'
        base3 = '&apiKey='+APIKEY+'&geometryType=polygon'
        
        #Alternate Bounding Box for North America
        #bbox='-140.0,25.0,-50.0,50.0'

        for y in range(0,num_layers):
            low_limitS=str(low_limit[y])
            high_limitS=str(high_limit[y])
            base4='&threshold='+low_limitS+':'+high_limitS  
            url = base1 + base2 + base3 + base4  # make API URL
            print ("Feature Call: " + url)
            data = requests.get(url).json() #Our API Call

            for z in data['features']:
                f = {"type": "Feature", "properties": {}, "geometry": None}
                f['geometry'] = z['geometry']
                WindGust = z['properties']['threshold']
                WindGust = WindGust[0:4]
                WindGust = float(WindGust)*2.2369
                WindGust = round(WindGust,1)
                f['properties']['WindGustMPH'] = WindGust  # y['properties']['threshold']
                f['properties']['Date'] = ts
                fc['features'].append(f)    

    filename="cannedWindGust"+calltime+".geojson"
    with open(filename, "w") as outfile:
        json.dump(fc, outfile)

################################################################################
# Get Time
now=datetime.datetime.utcnow()
year=str(now.year)
month=str('{:02d}'.format(now.month))
day=str('{:02d}'.format(now.day))
hour=str('{:02d}'.format(now.hour))
minute=str('{:02d}'.format(now.minute))
calltime=year+month+day+hour+minute

APIcall(calltime) # Function to grab data
print('done')
# Out:
# https://api.weather.com/v2/tiler/info?products=40:Windspeedgustsurface&apiKey=adb91efe0a544845b91efe0a542845f3
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=0.001:4.471
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=4.471:6.711
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=6.711:8.941
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=8.941:11.17
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=11.17:13.41
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=13.41:15.64
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=15.64:17.88
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=17.88:20.11
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=20.11:22.35
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=22.35:24.58
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=24.58:26.82
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=26.82:29.0576
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=29.0576:31.2928
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=31.2928:33.528
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=33.528:35.7632
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=35.7632:37.9984
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=37.9984:40.2336
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=40.2336:42.4688
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=42.4688:44.704
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=44.704:46.9392
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=46.9392:49.1744
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=49.1744:51.4096
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=51.4096:53.6448
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=53.6448:55.88
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=55.88:58.1152
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=58.1152:60.3504
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=60.3504:62.5856
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=62.5856:64.8208
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=64.8208:67.056
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=67.056:69.2912
# Feature Call: https://api.weather.com/v2/featurizer/isoband?product=40:Windspeedgustsurface&t=1732554300000&bbox=-140.0,25.0,-50.0,50.0&apiKey=adb91efe0a544845b91efe0a542845f3&geometryType=polygon&threshold=69.2912:71.52
# done

# %% [markdown]
# **Optional:** If you would like to run this notebook in a cloud based data science tool like IBM's Cloud Pak for Data, you will need to push the geojson file to cloud object storage. In that case, each project will have it's own unique id or access token that would need to be adjusted.

# %%
# from project_lib import Project # allows access to COS

# # Our COS info
# project = Project(project_id='c1d1ddd6-9a7d-4b23-84b1-a5fe8f5e7282', project_access_token='p-b122bebf800f2e545d1ad3823c989c42e2409684')
# pc = project.project_context

# f0 = open("cannedRadar"+calltime+".geojson","r",encoding='utf-8')
# aa = f0.read()

# print("Save to Cloud Storage")

# project.save_data("cannedRadar"+calltime+".geojson", aa ,set_project_asset=True, overwrite=True)
